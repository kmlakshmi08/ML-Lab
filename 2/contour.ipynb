# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('ToyotaCorolla.csv')
x=df['KM']
y=df['Weight']
z=['Price']

plt.tricontourf(x,y,x,levels=20,cmap='jet')
plt.colorbar(label='Price')
plt.title('contour plot')
plt.show()
