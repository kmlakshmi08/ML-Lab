# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv('ToyotaCorolla.csv')
df=data[['Price','KM','HP','Weight','Automatic']]

sns.heatmap(df.corr())
plt.title('Heatmmap')
plt.show()
